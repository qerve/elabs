# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# %%
#I_p = 5mA
U2 = np.array([25.01,
22.11,
19.23,
16.04,
13.02,
10.00,
8.04  ,
6.01  ,
4.12  ,
2.10  ,
0.54  ,
-24.99,
-22.03,
-19.02,
-16.12,
-13.00,
-10.13,
-8.06 ,
-6.12 ,
-4.02 ,
-2.02, 
-0.54])
U2r = np.array([4.12  ,
2.10  ,
0.54  ])

# %%
I2 = np.array([
     126.20  ,
 122.84  ,
 119.52  ,
 114.79  ,
 108.13  ,
 97.96    ,
 86.26     ,
 71.00     ,
 53.02     ,
 28.54     ,
 7.63       ,
 -139.73,
 -136.27,
 -132.46,
 -128.01,
 -120.47,
 -109.59,
 -98.48  , 
 -83.83   ,
 -64.11   ,
 -40.20   ,
 -20.79   
])
I2r = np.array([ 53.02     ,
 28.54     ,
 7.63       ])

a2, b2 = np.polyfit(I2r, U2r, deg=1)
y_est2 = a2 * I2 + b2
fig, ax = plt.subplots()
ax.plot(I2, y_est2, '-', label = '$k = 0,079 \; В/мкА , \; \; I_{iH} = 94 мкА$', color = 'red')
ax.legend()
ax.grid()
ax.set_xlabel('$I_{2}, мкА$')
ax.set_ylabel('$U_{2}, В$')
ax.plot(I2, U2, '.', color='blue')
print(a2, b2)
fig.savefig('50.pdf')
# Out:
# 0.07897484543960369 -0.09458882158608413

# %%
plt.grid()
plt.title("$I_{p} = 5 мА$")
plt.xlabel("$I_{2}, мкА$")
plt.ylabel("$U_{2}, В$")

plt.plot(I2, U2, color="blue", marker="o")
plt.savefig('5_0.pdf')

# %%
U3 = np.array([
     25.13 ,
 22.23  ,
 19.14  ,
 16.23  ,
 13.12  ,
 10.21   ,
8.04      ,
5.98      ,
4.14      ,
2.04      ,
0.48       ,
 -24.98,
 -22.09,
 -19.17,
 -16.17,
 -13.25,
 -10.05,
-8.16   , 
-5.98    ,
-4.11     ,
-2.05    ,
-0.57    
])
U3r = np.array([4.14      ,
2.04      ,
0.48       ])

# %%
I3 = np.array([
      66.86 ,
 65.03  ,
 62.97  ,
 60.95  ,
 57.65  ,
 52.78   ,
 46.57    , 
 37.85     ,
 27.46     ,
 12.96     ,
0.085      ,
 -77.00,
 -74.82,
 -72.64,
 -70.34,
 -67.17,
 -61.57,
 -55.87 ,  
 -46.69  , 
 -36.10   , 
 -21.73   ,
 -10.27   
])
I3r = np.array([ 27.46     ,
 12.96     ,
0.085      ])
a3, b3 = np.polyfit(I3r, U3r, deg=1)
y_est3 = a3 * I3 + b3
fig, ax = plt.subplots()
ax.plot(I3, y_est3, '-', label = '$k = 0,134 \; В/мкА , \; \; I_{iH} = 51 мкА$', color = 'red')
ax.legend()
ax.grid()
ax.set_xlabel('$I_{2}, мкА$')
ax.set_ylabel('$U_{2}, В$')
ax.plot(I3, U3, '.', color='blue')
print(a3, b3)
fig.savefig('30.pdf')
# Out:
# 0.13393163579818398 0.41169969733151923

# %%
plt.grid()
plt.title("$I_{p} = 3 мА$")
plt.xlabel("$I_{2}, мкА$")
plt.ylabel("$U_{2}, В$")

plt.plot(I3, U3, color="blue", marker="o")
plt.savefig('3_0.pdf')

# %%
U4 = np.array([
      25.15 ,
 22.09  ,
 19.06  ,
 16.09  ,
 13.13  ,
10.18   ,
7.98     ,  
5.99      , 
4.03       ,
2.13       ,
0.52        ,
 -25.11,
 -23.02,
 -18.96,
 -16.12,
 -13.09,
 -10.04,
 -8.03  ,   
 -6.26   ,  
-4.04     , 
 -2.05     ,
 -0.47     
])
U4r = np.array([4.03       ,
2.13       ,
0.52       ])

# %%
I4 = np.array([
     33.67 ,
32.50  ,
31.36  ,
30.18  ,
 28.78  ,
26.37   ,
 23.24   ,   
 19.09    ,  
 13.50     , 
 6.61       , 
0.04         ,
 -40.02,
  -39.05,
  -37.15,
  -35.90,
  -34.20,
  -31.49,
 -28.49  ,  
 -24.73   , 
 -18.30    ,
 -11.05    ,
 -4.56      
])
I4r = np.array([ 13.50     , 
 6.61       , 
0.04 ])
a4, b4 = np.polyfit(I4r, U4r, deg=1)
y_est4 = a4 * I4 + b4
fig, ax = plt.subplots()
ax.plot(I4, y_est4, '-', label = '$k = 0,261 \; В/мкA , \; \; I_{iH} = 26 мкА$', color = 'red')
ax.legend()
ax.grid()
ax.set_xlabel('$I_{2}, мкА$')
ax.set_ylabel('$U_{2}, В$')
ax.plot(I4, U4, '.', color='blue')
print(a4, b4)
fig.savefig('15.pdf')
# Out:
# 0.2608942469075666 0.474326974937511

# %%
plt.grid()
plt.title("$I_{p} = 1,5 мА$")
plt.xlabel("$I_{2}, мкА$")
plt.ylabel("$U_{2}, В$")

plt.plot(I4, U4, color="blue", marker="o")
plt.savefig('1_5.pdf')

# %%
U1 = np.array([23.9 , 24.15 , 24.35 , 24.4 , 24.81 , 25.40 , 26.20 , 27.71 , 30.92 , 34.19 , 35.09])
I1 = np.array([4.60 , 4.04  , 3.56  , 3.12 , 2.80  , 2.36  , 2.00  , 1.56  , 1.20  , 0.80  , 0.52])
Ur = np.array([27.71 , 30.92 , 34.19])
Ir = np.array([1.56  , 1.20  , 0.80])

# %%
a1, b1 = np.polyfit(Ir, Ur, deg=1)
y_est1 = a1 * I1 + b1
fig, ax = plt.subplots()
ax.plot(I1, y_est1, '-', label = '$k = -8,52 \; В/мкА, R_{диф} = 8,5 * 10^{4} \; Ом$', color = 'red')
ax.legend()
ax.grid()
ax.set_xlabel('$I_{p}, мкА$')
ax.set_ylabel('$U_{1}, В$')
ax.plot(I1, U1, '.', color='blue')
print(a1, b1)
fig.savefig('uk.pdf')
# Out:
# -8.519833948339494 41.05020295202953

# %%
def fit_func(x, a, b):
    return a*x + b

params = curve_fit(fit_func, Ir, Ur)

[a, b] = params[0]
print(a, b)
# Out:
# -8.519833948816387 41.050202952595455
